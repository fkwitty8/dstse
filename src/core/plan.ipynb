# %%
# PROJECT OBJECTIVE
# to build  machine learning model that can predict rainfall intensity, duration, time, and clasify it likeheavy,moderate et al based on the provided dataset. 
# The model will be trained on historical weather data, including features such as temperature, humidity, wind speed, and atmospheric pressure. 
# The goal is to create a reliable predictive model that can assist in weather forecasting and help in planning activities that are affected by rainfall like traffic and university lecture.

# %%
# general steps for any dataset)
# 1. Data Cleaning and preprocessing
# 2. Data Visualization
# 3. Train Test Split
# 4. Model Building
# 5. Model Evaluation



# 1. Data Cleaning and preprocessing
# - Handle missing values to ensure completness
# - Handle outliers values to ensure accuracy and avoid skewing the model
# - Handle duplicates to ensure data integrity and avoid biasing the model
# - Handle inconsistent data types to ensure data consistency and avoid errors during analysis
# - Handle inconsistent data formats to ensure data consistency and avoid errors during analysis
# - Handle inconsistent data values to ensure data consistency and avoid errors during analysis
# - Handle inconsistent data labels to ensure data consistency and avoid errors during analysis
# - Handle inconsistent data encoding to ensure data consistency and avoid errors during analysis
# - Handle inconsistent data scaling to ensure data consistency and avoid errors during analysis
# - Handle inconsistent data normalization to ensure data consistency and avoid errors during analysis
# - Handle inconsistent data transformation 
# - Handle inconsistent data imputation

# 2. Data Visualization
# - Univariate Analysis
    # - Categorical Data
    # - Numerical Data
    
# - Bivariate Analysis
    # - Categorical vs Categorical
    # - Categorical vs Numerical
    # - Numerical vs Numerical
    
# - Multivariate Analysis
    # - Categorical vs Categorical vs Categorical
    # - Categorical vs Categorical vs Numerical
    # - Categorical vs Numerical vs Numerical
    # - Numerical vs Numerical vs Numerical
    # - Categorical vs Categorical vs Categorical vs Categorical
    # - Categorical vs Categorical vs Categorical vs Numerical
    # - Categorical vs Categorical vs Numerical vs Numerical
    # - Categorical vs Numerical vs Numerical vs Numerical
    # - Numerical vs Numerical vs Numerical vs Numerical
    
# - Time Series Analysis
# - Geospatial Analysis
# - Text Analysis
# - Image Analysis
# - Interactive Visualization
# - Dashboarding
# - Data Storytelling
# - Statistical Analysis
# - Hypothesis Testing
# - Regression Analysis
# - Classification Analysis
# - Clustering Analysis
    
# - Correlation Analysis
    # - Pearson Correlation
    # - Spearman Correlation
    # - Kendall Correlation
    # - Point Biserial Correlation
    # - Cramer's V Correlation
    # - Phi Coefficient Correlation
    # - Correlation Matrix
    # - Correlation Heatmap
    # - Correlation Pair Plot
    # - Correlation Scatter Plot
    # - Correlation Line Plot
    # - Correlation Bar Plot
    # - Correlation Box Plot
    # - Correlation Violin Plot
    # - Correlation Density Plot
    # - Correlation Distribution Plot
    # - Correlation Joint Plot
    # - Correlation Hexbin Plot
    # - Correlation KDE Plot
    # - Correlation Rug Plot
    # - Correlation Swarm Plot
    # - Correlation Strip Plot
    
# - Distribution Analysis
    # - Histogram
    # - Density Plot
    # - Box Plot

# 3. Train validate Test Split
# - Split the dataset into training, validation, and testing sets
# - Use the training set to train the model
# - Use the validation set to tune the model
# - Use the testing set to evaluate the model

# 4. Model Building
# - Choose the appropriate model for the problem
# - Train the model on the training set
# - Tune the hyperparameters of the model with the validation set

# 5. Model Evaluation
# - Evaluate the model on the testing set
# - Use appropriate evaluation metrics for the problem
# - Use confusion matrix, classification report, accuracy score, precision score, recall score, f1 score, cohen kappa score, roc auc score, etc. for classification problems
# - Use mean absolute error, mean squared error, root mean squared error, r2 score, etc. for regression problems
# - Use appropriate visualization techniques to visualize the results
# - Use appropriate techniques to interpret the results
# - Use appropriate techniques to communicate the results
